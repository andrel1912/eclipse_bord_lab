# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/solar.csv")

df.shape 
df.head()
df.dtypes
df.isna().sum()
# Out:
# Catalog Number          0
# Calendar Date           0
# Eclipse Time            0
# Delta T (s)             0
# Lunation Number         0
# Saros Number            0
# Eclipse Type            0
# Gamma                   0
# Eclipse Magnitude       0
# Latitude                0
# Longitude               0
# Sun Altitude            0
# Sun Azimuth             0
# Path Width (km)      4200
# Central Duration     4200
# dtype: int64
