# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/solar.csv")

df.shape 
df.head()
df.dtypes
df.isna().sum()
# Out:
# Catalog Number          0
# Calendar Date           0
# Eclipse Time            0
# Delta T (s)             0
# Lunation Number         0
# Saros Number            0
# Eclipse Type            0
# Gamma                   0
# Eclipse Magnitude       0
# Latitude                0
# Longitude               0
# Sun Altitude            0
# Sun Azimuth             0
# Path Width (km)      4200
# Central Duration     4200
# dtype: int64

# %%
# Summarizes the dataset
df.describe(include="all")
# Out:
#         Catalog Number  Calendar Date Eclipse Time   Delta T (s)  \
# count     11898.000000          11898        11898  11898.000000
# unique             NaN          11898        11154           NaN
# top                NaN  -1999 June 12     00:40:11           NaN
# freq               NaN              1            4           NaN
# mean       5949.500000            NaN          NaN  12142.172802
# std        3434.801086            NaN          NaN  13583.402888
# min           1.000000            NaN          NaN     -6.000000
# 25%        2975.250000            NaN          NaN    970.250000
# 50%        5949.500000            NaN          NaN   5636.500000
# 75%        8923.750000            NaN          NaN  20943.500000
# max       11898.000000            NaN          NaN  46438.000000
#
#         Lunation Number  Saros Number Eclipse Type         Gamma  \
# count      11898.000000  11898.000000        11898  11898.000000
# unique              NaN           NaN           19           NaN
# top                 NaN           NaN            P           NaN
# freq                NaN           NaN         3875           NaN
# mean      -18546.959321     87.483190          NaN     -0.002469
# std        17906.572982     48.380284          NaN      0.900860
# min       -49456.000000    -13.000000          NaN     -1.569000
# 25%       -33954.750000     47.000000          NaN     -0.786575
# 50%       -18495.000000     87.000000          NaN     -0.003850
# 75%        -3039.250000    128.000000          NaN      0.776900
# max        12378.000000    190.000000          NaN      1.570600
#
#         Eclipse Magnitude Latitude Longitude  Sun Altitude   Sun Azimuth  \
# count        11898.000000    11898     11898  11898.000000  11898.000000
# unique                NaN     1654      3448           NaN           NaN
# top                   NaN    61.0S    151.7W           NaN           NaN
# freq                  NaN       69        10           NaN           NaN
# mean             0.812748      NaN       NaN     36.505295    180.264330
# std              0.300398      NaN       NaN     32.417350    110.745408
# min              0.000000      NaN       NaN      0.000000      0.000000
# 25%              0.675925      NaN       NaN      0.000000     89.000000
# 50%              0.950600      NaN       NaN     38.000000    180.000000
# 75%              1.018400      NaN       NaN     66.000000    272.000000
# max              1.081300      NaN       NaN     90.000000    360.000000
#
#        Path Width (km) Central Duration
# count             7698             7698
# unique             754              679
# top                  -                -
# freq               181               94
# mean               NaN              NaN
# std                NaN              NaN
# min                NaN              NaN
# 25%                NaN              NaN
# 50%                NaN              NaN
# 75%                NaN              NaN
# max                NaN              NaN
